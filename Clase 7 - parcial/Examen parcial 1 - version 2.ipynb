# %% [markdown]
# ![Screenshot_33.png](attachment:Screenshot_33.png)

# %% [raw]
# Nombre: _________________________________________________________________

# %% [markdown]
# Recomendaciones:
#
# - El examen está diseñado para durar 2 horas, realicelo con tranquilidad.
# - La primera hora del examen está enfocado en la parte conceptural y teórica de los temas vistos hasta la clase 5.
# - La segunda hora del examen está enfocado en la parte práctica, donde se hará uso de Python para la solución.
# - Recuerde que solo puede sacar apuntes para la parte práctica.
# - Ayudarse de los apuntes principalmente tomados de la clase.
#
#
# **¡Mucho éxitos en su examen!**

# %% [markdown]
# ## Pregunta 1

# %% [markdown]
# Los primeros pasos de la programación están basados en aprender a estructurar instrucciones por medio de pseudocódigo y diagramas de flujo, según lo visto en clase, los diagramas de flujo describen el proceso de un sistema o programa. Permite entender su comportamiento.
#
# El diagrama presentado a continuación, se encarga de describir el flujo de un sistema que cuenta con la funcionalidad de login, donde se solicita una contraseña y un usuario. El diagrama debe contar con inicio, proceso, entrada, condición y fin. Identifique donde está el error del diagrama de flujo

# %% [markdown]
# ![Diagramas%20parcial.jpg](attachment:Diagramas%20parcial.jpg)

# %% [markdown]
# Resuelva el error encontrado en el diagrama de flujo, pero además permita al usuario reintentar solo tres veces, si el usuario supera el limite de intentos, el flujo debe terminar.

# %% [markdown]
# ## Pregunta 2
#
# El elemento presentado a continuación, realizar una acción o proceso dentro del flujo:

# %% [markdown]
# ![Screenshot_35.png](attachment:Screenshot_35.png)

# %% [markdown]
# **A**   Verdadero
# **B**   Falso

# %% [markdown]
# ## Pregunta 3

# %% [markdown]
# El pseudocódigo son instrucciones, secuencias de pasos diseñados de manera lógiica sobre el funcionamiento de un programa pero en lenguaje natural. A partir de esta definición el pseudocódigo que se presenta a continuación que funcionalidad está realizando:

# %% [markdown]
# ![Screenshot_36.png](attachment:Screenshot_36.png)

# %% [markdown]
# **A** Realizar la captura de un valor y operarlo por 0.19
# **B** Pedir el valor de un producto a un usuario y calcular el iva, adicionalmente aplicar un descuento de 3000 si el valor incluido el iva es mayor a 20.000
# **C** Pedir un valor de un producto, calcular el iva y validar el valor resultante para aplicar un descuento, luego volverlo a operar y aumentarle al valor del iva 3.000
# **D** Quitarle 3.000 al valor del producto porque el sistema aplica descuentos

# %% [markdown]
# ## Pregunta 4

# %% [markdown]
# A partir de la pregunta anterior (Pregunta 3), si el ejercicio es ejecutado en PSEINT y el valor del producto ingresado es 15.000 el resultado debería ser
#
# **A** El producto NO aplica descuento,  Valor real del producto: 17850, Valor total a pagar del producto: 17850
# **B** El producto APLICA descuento,  Valor real del producto: 17850, Valor total a pagar del producto: 17850
# **C** El producto NO aplica descuento, Valor total a pagar del producto: 19850
# **D** Ninguna de las anteriores

# %% [markdown]
# ## Pregunta 5
#
# Si en un programa, se está realizando una división de la cual se requiere obtener la respuesta sin valores decimales, cual sería el operador que arroja la respuesta esperada
#
# **A** %
# **B** /
# **C** //
# **D** *

# %% [markdown]
# ## Pregunta 6

# %% [markdown]
# **Un traductor o interprete**, Convierte el código de alto nivel y lo traduce a lenguaje de máquina para que este pueda ser comprendido. Mientras este se traduce, se va ejecutando y la máquina va realizando las instrucciones
#
#
# **A** Falso
# **B** Verdadero

# %% [markdown]
# ## Pregunta 7

# %% [markdown]
# Teniendo en cuenta lo que es un traductor o interprete y según la definición dada, es correcto decir que Python es un lenguaje compilado
#
# **A** Falso
# **B** Verdero

# %% [markdown]
# ## Pregunta 8

# %% [markdown]
# Cuando queremos recibir datos de un usuario en Python que comando deberíamos escribir en nuestro código:
#
# **A** print()
# **B** Escribir
# **C** Leer
# **D** input()

# %% [markdown]
# ## Pregunta 9

# %% [markdown]
# Cuando el usuario ingresa un valor, el dato almacenado en la variable es de tipo texto. Si más adelante el sistema necesita hacer una operación numerica que permita operar decimales, cual cast o conversión sería la correcta
#
# **A** float(value_input)
# **B** str(value_input)
# **C** int(value_input)
# **D** Ninguna de las anteriores

# %% [markdown]
# ## Pregunta 9

# %% [markdown]
# ¿Qué sucede si en Python se tiene la siguiente linea de código?
#
# mi_numero = 2
# mi_variable = "hola, esto es una prueba" + mi_numero

# %% [markdown]
# **A** El sistema debería arrojar error pues no es posible operar un número con una cadena de texto
# **B** El sistema concatenará y mostrará lo siguiente "hola, esto es una prueba 2"
# **C** El sistema no se ejecutará y continuará con otro flujo
# **D** El sistema transforma automáticamente el número en cadena de texto

# %% [markdown]
# ## Pregunta 10

# %% [markdown]
# La lógica proposicional en la base de las condiciones en Python. Existen operadores lógicos los cuales permiten obtener una respuesta falsa o verdadera. Los operadores son AND (^), OR (v), XOR.
#
# Teniendo en cuenta que el caso de AND para que las premisas se cumplan ambas deben ser verdaderas y en el caso de OR, solo es necesario que una de las premisas sea verdadera resuelva las siguientes tablas de verdad.

# %% [markdown]
# 1. (p^¬q)v¬p
# 2. (¬pv¬q)^q

# %% [markdown]
# ## Pregunta 11

# %% [markdown]
# Realice una implementación en Python en le permita ejecutar el pseudocódigo de la pregunta 3. Es necesario pedir el dato, hacer el cast o conversión del mismo y operarlo utilizando el módulo.
# Adjunte su script de Python en el hilo dejado en Teams.
