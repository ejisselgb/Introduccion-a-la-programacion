# %% [markdown]
# # Clase 2 - Pseudocódigo y diagramas de flujo

# %% [markdown]
# ### Corte I - Algoritmos, diagramas y lógica
#
#  - Pseudocódigo y diagramas de flujo
#  - Lógica booleana
#  - Abstracción y patrones

# %% [markdown]
# ## ¿Qué es un algoritmo?
#
# `Un algoritmo se define como el conjunto de instrucciones que son seguidas y realizadas por una tarea particular.
# Un algoritmo está compuesto por un conjunto de pasos finitos, los cuales requieren una o más operaciones.`

# %% [markdown]
# Los algoritmos deben satisfacer los siguientes criterios:
#
# - Entrada: Puede ser una cadena de texto, un numero, un símbolo.
# - Salida: Resultado de los procesos realizados por el algoritmo, es lo esperado por el usuario.
# - Definición: Las instrucciones deben ser claras, ordenadas y no ambiguas.
# - Finitud: Todos los algoritmos deben tener un número determinado de pasos para realizarse. Las instrucciones son limitadas.
# - Efectividad: Cada instrucción debe ser básica para que pueda ser llevada a cabo, en principio por una persona usando solo lápiz y papel.

# %% [markdown]
# Teniendo en cuenta los elementos que conforman un algoritmo, ¿qué es para tí un algoritmo? y ¿cómo sería para tí un algoritmo?, construye un ejemplo, puedes basarte en eventos del día a día o de tu carrera.

# %% [markdown]
# **Tener en cuenta que los algoritmos presentan los siguientes momentos o ciclo de vida:**
#
# 1. Análisis del problema, estableciendo con precisión lo que se plantea.
# 2. Solución conceptual del problema, describiendo un método (algoritmo) que lo resuelva.
# 3. Escritura del algoritmo en un lenguaje de programación

# %% [markdown]
# Definición de un algoritmo:
# ![image.png](attachment:image.png)

# %% [markdown]
# Un algoritmo es:
#
# - Preciso
# - Determinista
# - Finito

# %% [markdown]
# No todos los problemas, pueden resolverse de manera computacional como se esperaría, por ejemplo, algunos son de gran magnitud, teniendo la posibilidad de dar infinitas soluciones por lo que a nivel computacional no sería optimo ni viable.
#
# Imagina algo que no pueda ser representado a nivel computacional, da un ejemplo. También da un ejemplo de 3 casos de la vida cotidiana que puedan representarse por medio de algoritmos.

# %% [markdown]
# Para resolver un problema por medio de algoritmos es necesario identificar las acciones que conducen a la solución, describirlar y organizarlas. Resuelve el siguiente problema: **Contar de manera regresiva y de 2 en 2 números del 20 al 0**
#
# Debes lograr:
# - Identificar cuáles son los datos y resultados
# - Describir la complejidad del problema
# - Identificar lo pasos del algoritmo para hacer la cuenta de 2 en 2 de manera regresiva
# - Determinar si este problema puede ser llevado a un ambiente computacional

# %% [markdown]
# ## ¿Qué es un diagrama de flujo?

# %% [markdown]
# Un diagrama de flujo describe el proceso de un sistema o programa. Permite comprender como se comporta un sistema,
# como es la comunicación de cada componente o funcionalidad y a su vez como es la comunicación con los usuarios, como es la manera de mostrar los resultados.

# %% [markdown]
# ### Símbolos o componentes de un diagrama de flujo

# %% [markdown]
# <p style="text-align: center;">Fin del flujo</p>

# %% [markdown]
# ![d1.png](attachment:d1.png)

# %% [markdown]
# <p style="text-align: center;">Procesos o tareas a realizar dentro del flujo</p>

# %% [markdown]
# ![d2.png](attachment:d2.png)

# %% [markdown]
# <p style="text-align: center;">Entrada o salida de datos</p>

# %% [markdown]
# ![d5.png](attachment:d5.png)

# %% [markdown]
# <p style="text-align: center;">Mostrar resultados de un proceso en un archivo como salida</p>

# %% [markdown]
# ![d3.png](attachment:d3.png)

# %% [markdown]
# <p style="text-align: center;">Tomar decisiones dentro del sistema</p>

# %% [markdown]
# ![d4.png](attachment:d4.png)

# %% [markdown]
# <p style="text-align: center;">Conectar y armar flujos</p>

# %% [markdown]
# ![d6.png](attachment:d6.png)

# %% [markdown]
# ## ¿Cómo construir un diagrama de flujo?

# %% [markdown]
# ![df1.png](attachment:df1.png)

# %% [markdown]
# En el diagrama de flujo es posible visualizar los cambios de variables, el comportamiento de un sistema frente a una condición, respuesta al usuario, cuantas veces se repetirá el flujo y en que momento finalizará.
#
# Teniendo en cuenta que ya conocemos el algoritmo del conteo regresivo de números de 0 a 20 de 2 en 2, ¿de qué manera representarías esto en un diagrama de flujo?

# %% [markdown]
# **Referencias:**
#
# - Algoritmos y Programación en Pascal, páginas 3 - 21
# - Libro: Fundamentals of computer algorithms, autor: Ellis Horowitz
# - Diagramas de flujo: https://www.lucidchart.com/pages/es/que-es-un-diagrama-de-flujo
