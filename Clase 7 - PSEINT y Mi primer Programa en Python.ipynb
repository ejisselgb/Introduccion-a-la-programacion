# %% [markdown]
# # Clase 7 - PSEINT y Mi primer Programa en Python

# %% [markdown]
# - Algoritmos y diagramas de flujo ✅
# - Lógica booleana ✅
# - Abstracción y patrones ✅
# - Pseudocódigo ✅

# %% [markdown]
# **Antes de continuar con la creación del programa en Python, ir a la clase 6 y realizar la sección práctica del uso de GIT**
#
# https://github.com/ejisselgb/Introduccion-a-la-programacion/blob/semestre-2022-1/Clase%206%20-%20PSEINT%20y%20GIT.ipynb

# %% [markdown]
# ## ¿Qué es un lenguaje de programación?
#
# Un lenguaje de programación es un conjunto de instrucciones que permite crear programas para controlar el comportamiento físico y lógico de una máquina. El programa puede dar órdenes, comparar valores, procesar y almacenar datos.
#
# Un lenguaje de programación posee un conjunto de reglas semánticas que le dan orden y estructura, además permite que una persona pueda comunicarse con una máquina por medio de símbolos y palabras claves.
#
# También es una herramienta que permite desarrollar software o programas para computadora. Los lenguajes de programación se utilizan para diseñar e implementar programas encargados de definir y administrar el comportamiento de los dispositivos físicos y lógicos de una computadora. Lo anterior se logra mediante la creación e implementación de algoritmos.

# %% [markdown]
# ## Tipos de lenguajes de programación
#
# En la programación existen varios tipos de lenguajes, los cuales han sido desarrollados para cumplir un objetivo o tarea específica. Pueden estar destinados a aplicaciones para análisis de datos, inteligencia artificial, programación de controladores y hardware, aplicaciones web o móviles.
# Los tipos de lenguajes se presentan a continuación:
#
# ### Bajo nivel
# El código de bajo nivel trabaja a gran velocidad, es de fácil conversión para la máquina, pero puede ser complejo para el programador escribirlo, dado que su sintaxis está muy ligada al lenguaje del hardware.
#
# #### Código Binario
# Es un lenguaje básico conformado por los números 0 y 1. Permite procesar las instrucciones de una computadora, dadas desde código binario o por medio de un lenguaje de programación (interpretado o compilado), el cual su traducción se reduce a bits para que sea posible la lectura desde un computador. (más bajo nivel)
#
# #### Lenguaje máquina
# Lenguaje de programación diseñado para cada máquina, permitía la comunicación directa, pero era complejo construir código a través de este, pues era necesario aprender uno diferente para cada dispositivo. El código binario es lenguaje de máquina.
#
# #### Lenguaje emsamblador
# Lenguaje que utiliza códigos o abreviaturas que podían ser memorizadas, sin embargo requiere un traductor que convierta los programas construidos en este lenguaje a lenguaje de máquina. Fue el primer intento de creación de un lenguaje que fuera comprendido por los programadores pero que a su vez pudiera ser comprendido por la máquina a través de un intermediario.
#
# ![Codigo_de_maquina.png](attachment:Codigo_de_maquina.png)

# %% [markdown]
# ### Alto nivel
#
# Permiten la construcción de código a través de instrucciones dadas por medio del lenguaje que comúnmente utilizamos, estas pueden ser en inglés, español, etc. Los lenguajes de alto nivel no son comprendidos por la máquina por lo que deben pasar por un traductor o un compilador.

# %% [markdown]
# #### Traductor o intérprete:
# Convierte el código de alto nivel y lo traduce a lenguaje de máquina para que este pueda ser comprendido. Mientras este se traduce, se va ejecutando y la máquina va realizando las instrucciones.
#
# ![Screenshot_150.png](attachment:Screenshot_150.png)

# %% [markdown]
# #### Compilador
# Permite traducir todo un programa diseñado en un lenguaje de alto nivel a un lenguaje de máquina. Esta traducción es almacenada, por lo que no requiere una traducción por cada ejecución a no ser de que presente cambios.
#
# ![Screenshot_149.png](attachment:Screenshot_149.png)

# %% [markdown]
# ### ¿Qué es python?
#
# Python es un lenguaje de programación imperativo, de sintaxis limpia y de código libre. Es un lenguaje de alto nivel, el cual puede ser utilizado en diversas aplicaciones web, inteligencia artificial, analítica de datos y videojuegos.
#
# Es un lenguaje fácil de aprender ya que se asemeja al pseudocódigo, es un lenguaje multiplataforma, lo que se diseña en un sistema operativo por ejemplo Windows, funciona sin problemas en MacOS o Linux. Adicionalmente sirve para cualquier tipo de desarrollo, si se compara con R, este lenguaje solo sirve para analizar datos, mientras que Python, permite desarrollar aplicaciones móviles, sitios web, etc.

# %% [markdown]
# Algunas de las empresas más reconocidas que usan Python son:
#
# - Youtube
# - Netflix
# - Nasa

# %% [markdown]
# Python es un lenguja interpretado **NO** compilado, puede tener un **tipado fuerte** o un **tipado dinámico**. Hay 19 principios (zen of python) que influyen en el diseño del lenguaje, aquí veremos algunos de ellos interesantes, que deberíamos tener en cuenta cada vez que se construya un software, independientemente de su nivel de complejidad.
#
# - La legibilidad es importante
# - Los errores nunca deben pasar silenciosamente
# - Si la implementación es difícil de explicar es una mala idea
# - Frente a la ambiguedad, evitar la tentación de preguntar
# - Lo simple es mejor que lo complejo

# %% [markdown]
# ### Creando nuestro primer programa
#
# Para la creación de un programa en Python podemos ingresar al siguiente enlace https://jupyter.org/try-jupyter/lab/ y trabajar de manera remota, o descargar la herramienta de manera local, para ello se deben seguir los siguientes pasos.
#
# 1. Ir al siguiente enlace para comenzar la descarga: https://www.python.org/downloads/
# 2. Seleccionar la opción download en el menú superior
# 3. Presionar botón de descargar python 3.10.3 para iniciar la descarga
# 4. Iniciar el ejecutable descargado en el computador y selecionar las opciones ''Install launcher for all users'' y ''add python 3.10 to PATH''
#
# ![Screenshot_151.png](attachment:Screenshot_151.png)
# (Imagen de referencia)

# %% [markdown]
# 5. Presionar el botón **install now**
# 6. cuando finalice la instalación, abrir consola de comandos del computadory ejecutar el comando `python`
#
# #### ¿Cómo y dónde escribiremos nuestro código?
#
# Es posible descargar cualquier editor de texto, incluso es posible utilizar block de notas. Sin embargo, en la clase se propone hacer uso del editor de texto Visual Studio Code
#
# Link de descarga: https://code.visualstudio.com
#
# Ahora sigue los siguientes pasos:
#
# 1. Descargar el archivo, según el sistema operativo y ejecutar la aplicación descargada.
#
# 2. cuando finalice la instalación abre la aplicación con el logo que se muestra a continuación.
#
# ![Screenshot_152.png](attachment:Screenshot_152.png)
#
# 3. Da clic en la opción extensiones del menú lateral

# %% [markdown]
# ![Screenshot_153.png](attachment:Screenshot_153.png)
#
# 4. Busca la extensión Python, y da clic en instalar

# %% [markdown]
# ![Screenshot_154.png](attachment:Screenshot_154.png)

# %% [markdown]
# ### Creando mi primer programa en Python
#
# **Esta práctica se realizará sobre el ambiente remoto, sin embargo, si usted ejecutará el código de manera local, los comandos son lo mismo**
#
# https://jupyter.org/try-jupyter/lab/
#
# Al ingresar al link será necesario crear nuevo archivo para iniciar el desarrollo, del código para ello dar clic en el botón de "+" y luego seleccionar en la pestaña de notebook, la opción con el icono de Python.
#
# ![Screenshot_155.png](attachment:Screenshot_155.png)

# %% [markdown]
# Se creará un nuevo archivo, de clic derecho sobre el archivo sin nombre para asignar uno "MiPrimerPrograma"
#
# ![Screenshot_156.png](attachment:Screenshot_156.png)

# %% [markdown]
# Finalmente debería poder visualizarse algo igual a lo que se muestra en la image de abajo:
#
# ![Screenshot_157.png](attachment:Screenshot_157.png)

# %% [markdown]
# #### Referencias
#
# * Lenguajes de programación: https://programas.cuaed.unam.mx/repositorio/moodle/pluginfile.php/1023/mod_resource/content/1/contenido/index.html
# * ¿Qué es Python?: https://ellibrodepython.com/que-es-python
# * Descargar e instalar Python: https://ellibrodepython.com/descargar-instalar-python
# * A Python book: Beginning python, advanced python and python exercises, D Kuhlman, 2009"
